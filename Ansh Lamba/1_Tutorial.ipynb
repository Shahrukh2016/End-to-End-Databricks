# %% [markdown]
# ### 1. Data Reading

# %%
# df = spark.read.format('csv').option('inferSchema', True).option('header', True).load('ansh_lamba.default.master_data')

df = spark.read.table('ansh_lamba.default.master_data')

# %%
df.show()
