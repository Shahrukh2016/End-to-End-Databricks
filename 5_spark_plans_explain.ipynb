# %%
df = spark.table("workspace.default.imdb_movies")
df.show()

# %%
from pyspark.sql import functions as F

df_filtered = df.select("title", "imdb_rating", "release_year").filter(F.col("release_year") > 2010)
df_filtered.explain("extended")
