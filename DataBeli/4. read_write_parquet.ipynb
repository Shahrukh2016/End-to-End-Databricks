# %%
df = spark.read.format("json").load("/Volumes/databeli/test_tables/json_files/single_line.json")
display(df)

# %%
## Writing parquet
df.write.format("parquet").save("/Volumes/databeli/test_tables/parquet_files/single_line.parquet")

# %%
## Reading parquet
df = spark.read.format("parquet").load("/Volumes/databeli/test_tables/parquet_files/single_line.parquet")
display(df)
