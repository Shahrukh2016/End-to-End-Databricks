# %%
df = spark.table("samples.bakehouse.sales_franchises")
display(df)

# %%
df.write.saveAsTable("databeli.test_tables.sales_franchises_test")

# %%
df2 = df.limit(10)
df2.count()

# %%
df.printSchema()
