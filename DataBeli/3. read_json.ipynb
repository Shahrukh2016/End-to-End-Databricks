# %%
## Single Line 
df = spark.read.format("json").load("/Volumes/databeli/test_tables/json_files/single_line.json")
display(df)

# %%
## Multi Line
df = spark.read\
    .format("json")\
        .option("multiline", "true")\
            .load("/Volumes/databeli/test_tables/json_files/multi_line.json")
display(df)

# %%
df.write.format("json").save("/Volumes/databeli/test_tables/json_files/age_name_json")

# %%
df.write.format("csv").save("/Volumes/databeli/test_tables/json_files/age_name_csv")
