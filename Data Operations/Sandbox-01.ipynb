# %%
data = [
    ('Shahrukh', 'Data Scientist'),
    ('Vimal', 'Data Engineer'),
    ('Manjot', 'Data Analyst')
]
schema = 'name string, role string'
df = spark.createDataFrame(data, schema)
display(df)
